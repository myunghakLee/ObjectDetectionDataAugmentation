# %%
import os

file_list = os.listdir("Boat")

# %%
file_list.sort()
file_list
# Out:
# ['1_0.png',
#  '1_1.png',
#  '1_10.png',
#  '1_100.png',
#  '1_1000.png',
#  '1_1001.png',
#  '1_1002.png',
#  '1_1003.png',
#  '1_1004.png',
#  '1_1005.png',
#  '1_1006.png',
#  '1_1007.png',
#  '1_1008.png',
#  '1_1009.png',
#  '1_101.png',
#  '1_1010.png',
#  '1_1011.png',
#  '1_1012.png',
#  '1_1013.png',
#  '1_1014.png',
#  '1_1015.png',
#  '1_1016.png',
#  '1_1017.png',
#  '1_1018.png',
#  '1_1019.png',
#  '1_102.png',
#  '1_1020.png',
#  '1_1021.png',
#  '1_1022.png',
#  '1_1023.png',
#  '1_1024.png',
#  '1_1025.png',
#  '1_1026.png',
#  '1_1027.png',
#  '1_1028.png',
#  '1_1029.png',
#  '1_103.png',
#  '1_1030.png',
#  '1_1031.png',
#  '1_1032.png',
#  '1_1033.png',
#  '1_1034.png',
#  '1_1035.png',
#  '1_1036.png',
#  '1_1037.png',
#  '1_1038.png',
#  '1_1039.png',
#  '1_104.png',
#  '1_1040.png',
#  '1_1041.png',
#  '1_1042.png',
#  '1_1043.png',
#  '1_1044.png',
#  '1_1045.png',
#  '1_1046.png',
#  '1_1047.png',
#  '1_1048.png',
#  '1_1049.png',
#  '1_105.png',
# ...

# %%
boat_list = file_list[3350:3360]
boat_list
# Out:
# ['3_30.png',
#  '3_31.png',
#  '3_32.png',
#  '3_33.png',
#  '3_4.png',
#  '3_5.png',
#  '3_6.png',
#  '3_7.png',
#  '3_8.png',
#  '3_9.png']

# %%
from PIL import Image


im = Image.open("Boat/" + boat_list[0])
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=699x538 at 0x7F02B34F7AC8>
